# %%
from pynwb import NWBHDF5IO
import warnings
warnings.filterwarnings("ignore")

path = "/Users/sachuriga/Downloads/Rat6_20260629.nwb"

# keep io open so lazy datasets stay readable
io = NWBHDF5IO(path, mode="r", load_namespaces=True)
nwb = io.read()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 8
#       4
#       5 path = "/Volumes/genzelneuron/data/op6/Rat6_20260629.nwb"
#       6
#       7 # keep io open so lazy datasets stay readable
# ----> 8 io = NWBHDF5IO(path, mode="r", load_namespaces=True)
#       9 nwb = io.read()
#
# File /opt/miniconda3/envs/HM_neuron/lib/python3.13/site-packages/hdmf/utils.py:641, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     639 def func_call(*args, **kwargs):
#     640     pargs = _check_args(args, kwargs)
# --> 641     return func(args[0], **pargs)
#
# File /opt/miniconda3/envs/HM_neuron/lib/python3.13/site-packages/pynwb/__init__.py:409, in NWBHDF5IO.__init__(self, **kwargs)
#     407 if load_namespaces:
#     408     tm = get_type_map()
# --> 409     super().load_namespaces(tm, path, file=file_obj, driver=driver, aws_region=aws_region)
# ...

# %%
nwb
